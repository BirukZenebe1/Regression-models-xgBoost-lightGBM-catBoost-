# %% [markdown]
# <a href="https://colab.research.google.com/github/BirukZenebe1/Regression-models-xgBoost-lightGBM-catBoost-/blob/main/xgboost_regressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XGBoost Regressor

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Importing the dataset

# %%
import pandas as pd
dataset=pd.read_csv('insurance.csv')

# %%
dataset.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### Checking missing data

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# ### Handling categorical variables

# %% [markdown]
# Sex column

# %%
dataset['sex']=dataset['sex'].apply(lambda x: 0 if x == 'female' else 1)
dataset
# Out:
#       age  sex     bmi  children smoker     region      charges
# 0      19    0  27.900         0    yes  southwest  16884.92400
# 1      18    1  33.770         1     no  southeast   1725.55230
# 2      28    1  33.000         3     no  southeast   4449.46200
# 3      33    1  22.705         0     no  northwest  21984.47061
# 4      32    1  28.880         0     no  northwest   3866.85520
# ...   ...  ...     ...       ...    ...        ...          ...
# 1333   50    1  30.970         3     no  northwest  10600.54830
# 1334   18    0  31.920         0     no  northeast   2205.98080
# 1335   18    0  36.850         0     no  southeast   1629.83350
# 1336   21    0  25.800         0     no  southwest   2007.94500
# 1337   61    0  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Smoker column

# %%
dataset['smoker']=dataset['smoker'].apply(lambda x: 0 if x == 'no' else 1)
dataset.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %% [markdown]
# Region column

# %%
dataset['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
region_dummies = pd.get_dummies(dataset['region'],drop_first=True, dtype=int)
region_dummies
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
dataset= pd.concat([dataset,region_dummies],axis=1)
dataset
# Out:
#       age  sex     bmi  children  smoker     region      charges  northwest  \
# 0      19    0  27.900         0       1  southwest  16884.92400          0
# 1      18    1  33.770         1       0  southeast   1725.55230          0
# 2      28    1  33.000         3       0  southeast   4449.46200          0
# 3      33    1  22.705         0       0  northwest  21984.47061          1
# 4      32    1  28.880         0       0  northwest   3866.85520          1
# ...   ...  ...     ...       ...     ...        ...          ...        ...
# 1333   50    1  30.970         3       0  northwest  10600.54830          1
# 1334   18    0  31.920         0       0  northeast   2205.98080          0
# 1335   18    0  36.850         0       0  southeast   1629.83350          0
# 1336   21    0  25.800         0       0  southwest   2007.94500          0
# 1337   61    0  29.070         0       1  northwest  29141.36030          1
#
#       southeast  southwest
# 0             0          1
# 1             1          0
# 2             1          0
# 3             0          0
# 4             0          0
# ...         ...        ...
# 1333          0          0
# 1334          0          0
# 1335          1          0
# 1336          0          1
# 1337          0          0
#
# [1338 rows x 10 columns]

# %%
dataset=dataset.drop(['region'],axis=1)

# %%
dataset.head()
# Out:
#    age  sex     bmi  children  smoker      charges  northwest  southeast  \
# 0   19    0  27.900         0       1  16884.92400          0          0
# 1   18    1  33.770         1       0   1725.55230          0          1
# 2   28    1  33.000         3       0   4449.46200          0          1
# 3   33    1  22.705         0       0  21984.47061          1          0
# 4   32    1  28.880         0       0   3866.85520          1          0
#
#    southwest
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# ### Creating the Training Set and the Test Set

# %% [markdown]
# Getting the inputs and output

# %%
X=dataset.drop(['charges'],axis=1)
y=dataset['charges']

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %% [markdown]
# Getting the Training Set and the Test Set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state = 0)

# %% [markdown]
# ## Part 2 - Building and training the model

# %% [markdown]
# ### Building the model

# %%
from xgboost import XGBRegressor
model=XGBRegressor(max_depth = 2, learning_rate = 0.1, n_estimators = 150)

# %% [markdown]
# ### Training the model

# %%
model.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=2,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=150,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ### Inference

# %%
y_test
# Out:
# 578      9724.53000
# 610      8547.69130
# 569     45702.02235
# 1034    12950.07120
# 198      9644.25250
#            ...
# 1084    15019.76005
# 726      6664.68595
# 1132    20709.02034
# 725     40932.42950
# 963      9500.57305
# Name: charges, Length: 268, dtype: float64

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([12197.166 ,  9962.2295, 46630.34  , 14509.742 , 12136.312 ,
#         4054.3943,  2492.829 , 13114.509 ,  8589.051 ,  7178.061 ,
#         6481.2065, 11770.787 ,  9161.926 ,  5561.6597, 19983.664 ,
#        11565.331 , 13820.864 ,  5827.3755,  7852.7314, 35526.055 ,
#        25208.94  , 14246.345 , 12529.169 , 25137.383 ,  2980.6719,
#         7236.3413,  3450.8743,  8140.1006,  4772.8345, 11260.549 ,
#         8229.179 , 47979.195 , 14645.729 , 12094.871 , 16588.902 ,
#         5052.079 , 12405.351 , 37973.37  , 38941.797 ,  2568.9922,
#         4309.054 ,  4376.4336, 20536.    , 46474.285 , 36976.957 ,
#         5778.588 , 11565.331 ,  7249.85  ,  5276.7515, 12830.169 ,
#         5252.1196,  4947.262 , 25792.24  , 45012.996 , 11492.92  ,
#         5958.2803,  4519.926 , 10366.663 , 10079.341 , 15345.363 ,
#         2279.7495, 46162.62  , 16523.041 , 11243.455 , 13836.873 ,
#         9813.6   , 34951.53  , 39625.016 ,  4455.095 , 10205.354 ,
#        14559.453 , 12407.2705, 18800.668 , 14937.014 , 13965.8955,
#        14534.269 ,  8371.52  , 10463.872 , 21092.314 , 47396.426 ,
#        12168.152 , 43888.254 ,  3648.2717,  9189.879 , 42623.1   ,
#        21209.127 ,  4299.505 ,  4825.5312, 16097.54  , 37458.07  ,
#         7958.594 , 11999.576 ,  4671.554 ,  9902.3955,  6363.447 ,
#         6579.1504, 43291.605 , 37024.977 ,  7298.1978, 10978.133 ,
#         4211.2305,  7249.826 ,  6684.55  , 38780.938 , 23961.248 ,
#         4621.6724, 11632.565 ,  5636.619 , 12865.381 , 43444.93  ,
#        13308.136 ,  6060.6104, 10871.99  , 35376.957 , 46795.11  ,
#         7875.8184,  2843.0505, 10238.917 , 15392.54  ,  9828.69  ,
#        42561.246 , 13587.922 , 13405.131 ,  8781.985 , 10143.791 ,
#         6127.9375, 24879.398 , 24583.457 , 47230.363 ,  4277.9434,
#        10525.868 ,  4141.407 ,  7315.141 ,  9955.535 , 25692.645 ,
#        36683.35  , 22244.049 , 11848.58  , 26206.006 ,  5722.7153,
#         3732.3477, 12567.704 , 12486.22  , 12559.599 ,  6065.6064,
#        14900.721 , 15590.084 ,  5622.0737,  2240.4802, 12374.88  ,
#         7521.494 , 39662.855 , 11696.157 ,  4443.0195,  4711.7266,
#         7781.4536,  4809.0054,  3368.8735, 12178.9795, 11647.945 ,
#         7062.251 , 13608.717 , 14138.238 ,  9751.604 ,  3520.2292,
#         8000.577 , 16413.102 ,  7541.018 ,  6027.1733,  2565.9773,
#         7214.1216,  6631.0635, 11139.517 ,  4519.926 ,  6019.7334,
#         7386.929 ,  5625.981 ,  6629.5093, 29378.322 ,  2223.618 ,
#        14287.978 ,  8226.095 , 12611.045 ,  4785.8506,  6380.733 ,
#        27106.791 ,  3555.1929,  3523.7095, 15115.056 , 12002.849 ,
#        42150.023 ,  6411.542 ,  6097.332 , 24727.127 ,  5476.739 ,
#         3605.9905,  8585.845 ,  8527.305 ,  7020.7627,  6085.6577,
#        13216.092 , 45084.    , 14287.978 , 20514.602 ,  7329.279 ,
#        43646.04  ,  5362.202 , 12266.216 ,  7722.355 ,  2642.4656,
#        11314.883 , 14760.021 ,  6247.847 ,  3838.679 ,  6908.82  ,
#         3589.4414,  7619.264 ,  5916.346 , 15820.408 ,  6005.1646,
#         7933.925 ,  7652.2407,  9917.356 ,  3993.9275, 11718.327 ,
#        16423.463 , 15209.306 , 12260.461 ,  5948.808 ,  3828.3955,
#         3282.2844,  9666.314 , 13791.952 ,  6962.651 ,  5665.386 ,
#         7406.409 , 11290.882 , 36371.91  ,  7040.6055, 13435.685 ,
#         6865.9043, 39027.793 ,  7982.078 ,  8788.338 , 11111.809 ,
#        13154.749 ,  4169.2534, 10268.336 ,  2476.2805,  6737.3267,
#        20090.225 , 45652.766 ,  5379.4478,  4828.9404,  2959.8142,
#         2106.463 ,  8888.267 ,  3466.521 ,  6408.5757,  5665.386 ,
#         8643.203 , 26078.668 , 44126.973 , 17922.078 ,  7599.9966,
#        12045.285 , 40825.605 ,  9735.611 ], dtype=float32)

# %% [markdown]
# ## Part 3: Evaluating the model

# %% [markdown]
# ### R-Squared

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test, y_pred)
r2
# Out:
# 0.9024549670958453

# %% [markdown]
# ### Adjusted R-Squared

# %%
k=X_test.shape[1]
n=X_test.shape[0]
adj_r2 = 1 - (1 - r2) * (n - 1)/(n - k - 1)
adj_r2
# Out:
# 0.8994419931065277

# %% [markdown]
# ### k-Fold Cross Validation

# %%
from sklearn.model_selection import cross_val_score
k=10
r2s = cross_val_score(estimator=model, X=X, y=y, scoring='r2',cv=k)
print("Average r2:",r2s.mean().round(3))
print("Standard deviation r2:",r2s.std().round(3))
# Out:
# Average r2: 0.86
# Standard deviation r2: 0.044
